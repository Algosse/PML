# %%
import os
import matplotlib.pyplot as plt
from cocotool import COCO
# %matplotlib inline

# %%
coco = COCO("/home/space/datasets/pml_deformable_convolution/coco")
coco.loadAnnotationFile(typeData='val', typeAnnotation='instances')
#coco.loadAnnotationFile(typeData='train', typeAnnotation='instances')
print()
# Out:
# Loading instances_val2017.json
# instances_val2017.json loaded

# %%
trainData, testData = coco.loadInstancesData()

print(trainData, testData)

data = next(trainData)
print(data.keys())
plt.imshow(data['image'])
# Out:
# <generator object COCO.instancesToData at 0x14ffdecfd430> <generator object COCO.instancesToData at 0x14ffdecfd4a0>
# Loading instances_train2017.json
# instances_train2017.json loaded
# dict_keys(['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id', 'super_category', 'category_name', 'image'])

# %%
imageData = coco.getImageByFileName('139')
coco.showImageInstances(imageData)
plt.imshow(imageData['image'])
# Out:
# {'segmentation': [[240.86, 211.31, 240.16, 197.19, 236.98, 192.26, 237.34, 187.67, 245.8, 188.02, 243.33, 176.02, 250.39, 186.96, 251.8, 166.85, 255.33, 142.51, 253.21, 190.49, 261.68, 183.08, 258.86, 191.2, 260.98, 206.37, 254.63, 199.66, 252.51, 201.78, 251.8, 212.01]], 'area': 531.8071000000001, 'iscrowd': 0, 'image_id': 139, 'bbox': [236.98, 142.51, 24.7, 69.5], 'category_id': 64, 'id': 26547}
